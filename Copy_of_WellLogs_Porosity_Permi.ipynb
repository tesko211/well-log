# %% [markdown]
# <a href="https://colab.research.google.com/github/tesko211/well-log/blob/main/Copy_of_WellLogs_Porosity_Permi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q lasio scikit-learn
# allow wget (already present) and requests
import os, glob, sys
import requests
import lasio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

plt.rcParams['figure.figsize'] = (9,5)
print("Cell 1 done: packages installed and imports ready.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 2.0 MB/s eta 0:00:00
# Cell 1 done: packages installed and imports ready.

# %%
# Cell 2 — download files from GitHub repo (teacher's links -> raw content)
repo_user = "tesko211"
repo_name = "well-log"
branch = "main"   # teacher used main in links

filenames = ["A10","A15","A16","B2","B4","B8","B9","C1","C2","C3","C4","C5"]

outdir = "/content/github_files"
os.makedirs(outdir, exist_ok=True)

raw_base = f"https://raw.githubusercontent.com/{repo_user}/{repo_name}/{branch}/"

downloaded = []
for name in filenames:
    # try common variants/extensions: .las, .LAS, .csv, no extension
    tried = []
    success = False
    for ext in [".las", ".LAS", ".csv", ""]:
        url = raw_base + name + ext
        tried.append(url)
        try:
            r = requests.get(url, timeout=20)
            if r.status_code == 200 and len(r.content) > 0:
                # save file
                # If no extension in URL but content-disposition may exist — we keep ext as found
                outpath = os.path.join(outdir, name + (ext if ext else ""))
                with open(outpath, "wb") as f:
                    f.write(r.content)
                downloaded.append(outpath)
                print(f"Downloaded: {url} -> {outpath} (size={os.path.getsize(outpath)} bytes)")
                success = True
                break
        except Exception as e:
            pass
    if not success:
        print(f"WARNING: Could not download {name}. Tried URLs:\n  " + "\n  ".join(tried))

print("\nDownload complete. Files in folder:")
print(sorted(os.listdir(outdir)))
# Out:
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/A10 -> /content/github_files/A10 (size=147863 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/A15 -> /content/github_files/A15 (size=45223 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/A16 -> /content/github_files/A16 (size=57143 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/B2 -> /content/github_files/B2 (size=186822 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/B4 -> /content/github_files/B4 (size=202982 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/B8 -> /content/github_files/B8 (size=94822 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/B9 -> /content/github_files/B9 (size=202742 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/C1 -> /content/github_files/C1 (size=75702 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/C2 -> /content/github_files/C2 (size=88422 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/C3 -> /content/github_files/C3 (size=94182 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/C4 -> /content/github_files/C4 (size=122102 bytes)
# Downloaded: https://raw.githubusercontent.com/tesko211/well-log/main/C5 -> /content/github_files/C5 (size=86582 bytes)
#
# Download complete. Files in folder:
# ['A10', 'A15', 'A16', 'B2', 'B4', 'B8', 'B9', 'C1', 'C2', 'C3', 'C4', 'C5']

# %%
# Cell 3 — inspect files and detect type (LAS vs CSV)
folder = "/content/github_files"
files = sorted(os.listdir(folder))
info = []
for f in files:
    path = os.path.join(folder, f)
    size = os.path.getsize(path)
    kind = "unknown"
    # quick check: if file starts with "~Version" or "VERS." or "# LAS" -> LAS
    with open(path, "rb") as fh:
        head = fh.read(512).decode(errors='ignore').lower()
    if "las" in f.lower() or head.startswith('# las') or "version" in head and "well" in head:
        kind = "las"
    else:
        # try reading as CSV header
        try:
            sample = pd.read_csv(path, nrows=3)
            kind = "csv"
        except Exception:
            kind = "unknown"
    info.append((f, kind, size))
print("Files detected (name, type, bytes):")
for it in info:
    print(it)
# Out:
# Files detected (name, type, bytes):
# ('A10', 'las', 147863)
# ('A15', 'las', 45223)
# ('A16', 'las', 57143)
# ('B2', 'las', 186822)
# ('B4', 'las', 202982)
# ('B8', 'las', 94822)
# ('B9', 'las', 202742)
# ('C1', 'las', 75702)
# ('C2', 'las', 88422)
# ('C3', 'las', 94182)
# ('C4', 'las', 122102)
# ('C5', 'las', 86582)

# %%
# Cell 4 — read files (LAS -> lasio.df, CSV -> pd.read_csv), then concat
folder = "/content/github_files"
paths = sorted([os.path.join(folder, f) for f in os.listdir(folder)])
dfs = []
for p in paths:
    fname = os.path.basename(p)
    try:
        if fname.lower().endswith('.las'):
            las = lasio.read(p)
            df_temp = las.df()         # index typically is depth
            df_temp = df_temp.reset_index()
            df_temp['__source_file'] = fname
            dfs.append(df_temp)
            print("Read LAS:", fname, "shape:", df_temp.shape)
        elif fname.lower().endswith('.csv'):
            df_temp = pd.read_csv(p)
            df_temp['__source_file'] = fname
            dfs.append(df_temp)
            print("Read CSV:", fname, "shape:", df_temp.shape)
        else:
            # try to read as las first, then csv
            tried = False
            try:
                las = lasio.read(p)
                df_temp = las.df().reset_index()
                df_temp['__source_file'] = fname
                dfs.append(df_temp)
                print("Read (auto) LAS:", fname, "shape:", df_temp.shape)
                tried = True
            except Exception:
                pass
            if not tried:
                try:
                    df_temp = pd.read_csv(p)
                    df_temp['__source_file'] = fname
                    dfs.append(df_temp)
                    print("Read (auto) CSV:", fname, "shape:", df_temp.shape)
                except Exception as e:
                    print("ERROR reading file", fname, ":", e)
    except Exception as e:
        print("ERROR reading", fname, ":", e)

if not dfs:
    raise RuntimeError("No files were read successfully. Check previous output.")

# Combine
df = pd.concat(dfs, ignore_index=True, sort=False)
print("\nCombined df shape:", df.shape)
print("Columns:", list(df.columns)[:80])
# Out:
# Read (auto) LAS: A10 shape: (1835, 7)
# Read (auto) LAS: A15 shape: (552, 7)
# Read (auto) LAS: A16 shape: (701, 7)
# Read (auto) LAS: B2 shape: (2322, 7)
# Read (auto) LAS: B4 shape: (2524, 7)
# Read (auto) LAS: B8 shape: (1172, 7)
# Read (auto) LAS: B9 shape: (2521, 7)
# Read (auto) LAS: C1 shape: (933, 7)
# Read (auto) LAS: C2 shape: (1092, 7)
# Read (auto) LAS: C3 shape: (1164, 7)
# Read (auto) LAS: C4 shape: (1513, 7)
# Read (auto) LAS: C5 shape: (1069, 7)
#
# Combined df shape: (17398, 7)
# Columns: ['DEPT', 'GAMMA', 'PERM', 'POROSITY', 'RESISTIVITY', 'LITH', '__source_file']

# %%
# Cell 5 — coerce to numeric where possible and display columns
cols = [c for c in df.columns if c != '__source_file']
for c in cols:
    df[c] = pd.to_numeric(df[c], errors='coerce')

print("Columns available:")
print(list(df.columns))
print("\nQuick numeric summary (first 30 cols):")
display(df[cols].describe().T.head(30))
# Out:
# Columns available:
# ['DEPT', 'GAMMA', 'PERM', 'POROSITY', 'RESISTIVITY', 'LITH', '__source_file']
#
# Quick numeric summary (first 30 cols):
#                count         mean         std          min          25%  \
# DEPT         17398.0  2132.168185  296.879840  1467.488300  1929.900300
# GAMMA        17342.0    85.631054   20.820116    20.037910    74.117769
# PERM         17342.0     0.001362    0.001521     0.000006     0.000544
# POROSITY     17335.0     0.001589    0.000569     0.000000     0.001150
# RESISTIVITY  17329.0     6.948060   39.065088     0.000272     0.418047
# LITH         17333.0     1.599550    0.829981     0.000000     1.000000
#
#                      50%          75%          max
# DEPT         2113.496100  2326.749400  2991.917100
# GAMMA          83.013752    92.082531   159.749725
# PERM            0.000996     0.001671     0.029556
# POROSITY        0.001461     0.002109     0.003289
# RESISTIVITY     1.425442     4.321900  2252.267578
# LITH            1.000000     2.000000     3.000000

# %%
# Cell 6 — auto-detect porosity & permeability columns
def first_match(keywords):
    for k in keywords:
        for c in df.columns:
            if k in str(c).lower():
                return c
    return None

por = first_match(['phie','phit','porosity','poro','phi'])
perm = first_match(['permeability','perm','kperm','perm_','perme'])

# fallback for single-letter 'K'
if perm is None:
    for c in df.columns:
        if str(c).strip().lower() == 'k':
            perm = c
            break

print("Auto-detected por:", por)
print("Auto-detected perm:", perm)
if por is None or perm is None:
    print("\nAuto-detection failed for one or both targets.")
    print("Paste the EXACT column name here to set manually (copy it from the printed column list).")
# Out:
# Auto-detected por: POROSITY
# Auto-detected perm: PERM

# %%
# Cell 7 — pick features and clean dataset
preferred = ['GR','RHOB','NPHI','DT','RT','ILM','ILD','SP']
features = [c for c in preferred if c in df.columns]

# fallback: take up to 6 numeric columns excluding targets and __source_file
if len(features) < 2:
    candidate = [c for c in df.select_dtypes(include=[np.number]).columns if c not in (por, perm, '__source_file')]
    features = candidate[:6]

print("Features selected:", features)
# require targets present
df_targets = df.dropna(subset=[por, perm]).copy()
print("Rows with both targets:", len(df_targets))
if len(df_targets) < 50:
    raise RuntimeError("Too few rows with both targets present. Check por/perm names or files.")

# impute features median if necessary
if df_targets[features].isna().sum().sum() > 0:
    imputer = SimpleImputer(strategy='median')
    df_targets[features] = imputer.fit_transform(df_targets[features])
    print("Features imputed (median).")

df_clean = df_targets.reset_index(drop=True)
print("df_clean shape:", df_clean.shape)
display(df_clean[features + [por, perm]].head())
# Out:
# Features selected: ['DEPT', 'GAMMA', 'RESISTIVITY', 'LITH']
# Rows with both targets: 17333
# Features imputed (median).
# df_clean shape: (17333, 7)
#        DEPT      GAMMA  RESISTIVITY  LITH  POROSITY      PERM
# 0  1501.629  78.869453     0.709644   3.0  0.002674  0.001246
# 1  1502.129  78.008301     0.790188   3.0  0.002561  0.001253
# 2  1502.629  75.581558     0.780511   3.0  0.002421  0.001171
# 3  1503.129  73.238037     0.706579   3.0  0.002386  0.001096
# 4  1503.629  71.504173     0.661791   3.0  0.002384  0.001060

# %%
# Cell 8 — prepare arrays, scale, and split once
X = df_clean[features].values
y_por = df_clean[por].values
y_perm = df_clean[perm].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_por_train, y_por_test, y_perm_train, y_perm_test = train_test_split(
    X_scaled, y_por, y_perm, test_size=0.20, random_state=42
)

print("Shapes:")
print(" X_train", X_train.shape, "X_test", X_test.shape)
print(" y_por_train", y_por_train.shape, "y_por_test", y_por_test.shape)
# Out:
# Shapes:
#  X_train (13866, 4) X_test (3467, 4)
#  y_por_train (13866,) y_por_test (3467,)

# %%
# Cell 9 — train models
lr_por = LinearRegression().fit(X_train, y_por_train)
rf_por = RandomForestRegressor(n_estimators=200, random_state=42, n_jobs=-1).fit(X_train, y_por_train)

lr_perm = LinearRegression().fit(X_train, y_perm_train)
rf_perm = RandomForestRegressor(n_estimators=200, random_state=42, n_jobs=-1).fit(X_train, y_perm_train)

print("Models trained.")
# Out:
# Models trained.

# %%
# Cell 10 — evaluate & plot (compatible with older scikit-learn)
def metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = mse ** 0.5
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return {"r2": float(r2), "rmse": float(rmse), "mae": float(mae)}

y_por_pred_lr = lr_por.predict(X_test)
y_por_pred_rf = rf_por.predict(X_test)
y_perm_pred_lr = lr_perm.predict(X_test)
y_perm_pred_rf = rf_perm.predict(X_test)

print("Porosity - LR:", metrics(y_por_test, y_por_pred_lr))
print("Porosity - RF:", metrics(y_por_test, y_por_pred_rf))
print("Permeability - LR:", metrics(y_perm_test, y_perm_pred_lr))
print("Permeability - RF:", metrics(y_perm_test, y_perm_pred_rf))

# --- Plots ---
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(y_por_test, y_por_pred_rf, alpha=0.5, label='RF')
plt.scatter(y_por_test, y_por_pred_lr, alpha=0.3, label='LR')
plt.plot([min(y_por_test), max(y_por_test)], [min(y_por_test), max(y_por_test)], 'k--')
plt.xlabel("Actual Porosity"); plt.ylabel("Predicted"); plt.legend(); plt.title("Porosity")

plt.subplot(1,2,2)
plt.scatter(y_perm_test, y_perm_pred_rf, alpha=0.5, label='RF')
plt.scatter(y_perm_test, y_perm_pred_lr, alpha=0.3, label='LR')
try:
    plt.xscale('log'); plt.yscale('log')
except:
    pass
plt.plot([max(1e-9,min(y_perm_test)), max(y_perm_test)],
         [max(1e-9,min(y_perm_test)), max(y_perm_test)], 'k--')
plt.xlabel("Actual Permeability"); plt.ylabel("Predicted"); plt.legend(); plt.title("Permeability")
plt.tight_layout()
plt.show()
# Out:
# Porosity - LR: {'r2': 0.8770507643048915, 'rmse': 0.0001994581639916138, 'mae': 0.00015290583023094628}
# Porosity - RF: {'r2': 0.9535165803371373, 'rmse': 0.00012264163610876068, 'mae': 8.432073852986574e-05}
# Permeability - LR: {'r2': 0.5436233043232176, 'rmse': 0.0010615487457736284, 'mae': 0.0005601472713601626}
# Permeability - RF: {'r2': 0.9636016740495118, 'rmse': 0.0002997912249439022, 'mae': 0.00010918429999829325}

# %%
# Cell 11 — save results to Drive
from google.colab import drive
drive.mount('/content/drive')  # follow link & paste code

out_dir = "/content/drive/MyDrive/WellLogs_Project"
os.makedirs(out_dir, exist_ok=True)

# Save models and scaler
joblib.dump(rf_por, os.path.join(out_dir, 'rf_porosity.joblib'))
joblib.dump(rf_perm, os.path.join(out_dir, 'rf_permeability.joblib'))
joblib.dump(scaler, os.path.join(out_dir, 'scaler.joblib'))

# Save predictions
predictions = pd.DataFrame({
    'Actual_Porosity': y_por_test,
    'Pred_Porosity_RF': y_por_pred_rf,
    'Pred_Porosity_LR': y_por_pred_lr,
    'Actual_Perm': y_perm_test,
    'Pred_Perm_RF': y_perm_pred_rf,
    'Pred_Perm_LR': y_perm_pred_lr
})
predictions.to_csv(os.path.join(out_dir, 'predictions.csv'), index=False)
print("Saved models and predictions to Drive:", out_dir)

# To save the notebook to GitHub: Colab menu -> File -> Save a copy in GitHub (choose your repo & path)
print("Now use Colab: File -> Save a copy in GitHub to push notebook to your repository.")
# Out:
# Mounted at /content/drive
# Saved models and predictions to Drive: /content/drive/MyDrive/WellLogs_Project
# Now use Colab: File -> Save a copy in GitHub to push notebook to your repository.

# %%
# Final summary
print("✅ Training complete. Final model scores:")
print("Porosity - RandomForest R²:", metrics(y_por_test, y_por_pred_rf)['r2'])
print("Permeability - RandomForest R²:", metrics(y_perm_test, y_perm_pred_rf)['r2'])
# Out:
# ✅ Training complete. Final model scores:
# Porosity - RandomForest R²: 0.9535165803371373
# Permeability - RandomForest R²: 0.9636016740495118

# %%
joblib.dump(rf_por, "RF_Porosity_Model.pkl")
joblib.dump(rf_perm, "RF_Permeability_Model.pkl")
# Out:
# ['RF_Permeability_Model.pkl']

# %%
# ======================================================
# 📊 STEP 1 — Import visualization libraries
# ======================================================
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import r2_score

sns.set(style="whitegrid", palette="muted", font_scale=1.1)

# ======================================================
# ✅ STEP 2 — Define porosity & permeability columns
# ======================================================
# If you already defined them earlier, this will skip redefining
if "por_col" not in globals():
    # Automatically detect or ask for confirmation
    possible_por_cols = [c for c in df.columns if "phi" in c.lower() or "por" in c.lower()]
    possible_perm_cols = [c for c in df.columns if "perm" in c.lower() or c.lower() == "k"]
    print("Possible porosity columns:", possible_por_cols)
    print("Possible permeability columns:", possible_perm_cols)

    por_col = possible_por_cols[0] if possible_por_cols else input("Enter porosity column name: ")
    perm_col = possible_perm_cols[0] if possible_perm_cols else input("Enter permeability column name: ")

print("✅ Porosity column:", por_col)
print("✅ Permeability column:", perm_col)

# ======================================================
# 📈 STEP 3 — Correlation heatmap of numeric features
# ======================================================
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap of Well Log Parameters")
plt.tight_layout()
plt.savefig("/content/Correlation_Heatmap.png", dpi=300, bbox_inches='tight')
plt.show()

# ======================================================
# 📉 STEP 4 — Histogram / Distribution of Porosity & Permeability
# ======================================================
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.histplot(df_clean[por_col], bins=30, kde=True, color='royalblue')
plt.xlabel("Porosity")
plt.title("Distribution of Porosity")

plt.subplot(1,2,2)
sns.histplot(df_clean[perm_col], bins=30, kde=True, color='orange')
plt.xlabel("Permeability")
plt.title("Distribution of Permeability")

plt.tight_layout()
plt.savefig("/content/Porosity_Permeability_Distribution.png", dpi=300, bbox_inches='tight')
plt.show()

# ======================================================
# 🪶 STEP 5 — Predicted vs Actual Scatterplots
# ======================================================
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.scatter(y_por_test, y_por_pred_rf, alpha=0.6, label='Random Forest', color='green')
plt.scatter(y_por_test, y_por_pred_lr, alpha=0.4, label='Linear Regression', color='blue')
plt.plot([min(y_por_test), max(y_por_test)], [min(y_por_test), max(y_por_test)], 'k--')
plt.xlabel("Actual Porosity"); plt.ylabel("Predicted Porosity")
plt.legend(); plt.title("Porosity: Predicted vs Actual")

plt.subplot(1,2,2)
plt.scatter(y_perm_test, y_perm_pred_rf, alpha=0.6, label='Random Forest', color='red')
plt.scatter(y_perm_test, y_perm_pred_lr, alpha=0.4, label='Linear Regression', color='purple')
plt.plot([min(y_perm_test), max(y_perm_test)], [min(y_perm_test), max(y_perm_test)], 'k--')
plt.xlabel("Actual Permeability"); plt.ylabel("Predicted Permeability")
plt.legend(); plt.title("Permeability: Predicted vs Actual")

plt.tight_layout()
plt.savefig("/content/Predicted_vs_Actual.png", dpi=300, bbox_inches='tight')
plt.show()

# ======================================================
# 🌳 STEP 6 — Feature Importance (Random Forest)
# ======================================================
try:
    importances = rf_por.feature_importances_
    feat_imp = pd.DataFrame({'Feature': features, 'Importance': importances})
    feat_imp = feat_imp.sort_values(by='Importance', ascending=False)

    plt.figure(figsize=(8,4))
    sns.barplot(data=feat_imp, x='Importance', y='Feature', palette='viridis')
    plt.title("Feature Importance for Porosity Prediction (Random Forest)")
    plt.tight_layout()
    plt.savefig("/content/Feature_Importance_Porosity.png", dpi=300, bbox_inches='tight')
    plt.show()
except Exception as e:
    print("⚠️ Feature importance not available:", e)

# ======================================================
# 🧮 STEP 7 — Model Performance Comparison (R²)
# ======================================================
results = pd.DataFrame({
    "Model": ["Linear Regression", "Random Forest"],
    "Porosity R²": [
        r2_score(y_por_test, y_por_pred_lr),
        r2_score(y_por_test, y_por_pred_rf)
    ],
    "Permeability R²": [
        r2_score(y_perm_test, y_perm_pred_lr),
        r2_score(y_perm_test, y_perm_pred_rf)
    ]
})

results_melted = results.melt(id_vars="Model", var_name="Target", value_name="R² Score")

plt.figure(figsize=(8,5))
sns.barplot(data=results_melted, x="Model", y="R² Score", hue="Target")
plt.title("Model Performance Comparison (R² Score)")
plt.ylim(0,1)
plt.tight_layout()
plt.savefig("/content/Model_Performance_Comparison.png", dpi=300, bbox_inches='tight')
plt.show()

print("✅ All visualization steps completed successfully!")
print("🖼️ All images saved in /content/ as PNG files. You can download them from the Files tab.")
# Out:
# Possible porosity columns: ['POROSITY']
# Possible permeability columns: ['PERM']
# ✅ Porosity column: POROSITY
# ✅ Permeability column: PERM
# /tmp/ipython-input-3705359463.py:89: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=feat_imp, x='Importance', y='Feature', palette='viridis')
# ✅ All visualization steps completed successfully!
# 🖼️ All images saved in /content/ as PNG files. You can download them from the Files tab.

# %%
# !apt-get install graphviz -q
# !pip install graphviz -q
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
# ======================================================
# 🧩 WELL LOG INTERPRETATION WORKFLOW DIAGRAM
# ======================================================
from graphviz import Digraph
from IPython.display import Image

# Create a new directed graph
workflow = Digraph("WellLog_Workflow", format="png")
workflow.attr(rankdir='LR', size='8', splines='true')

# Node styling
workflow.attr('node', shape='rectangle', style='rounded,filled',
              color='lightgreen', fontsize='12', fontname='Arial')

# Define workflow steps
workflow.node("A", "1️⃣ Data Acquisition\nCollect LAS Well Log Files (A10–C5)")
workflow.node("B", "2️⃣ Data Preprocessing\nRead LAS, Clean, Merge, Scale")
workflow.node("C", "3️⃣ Feature Selection\nGR, RHOB, NPHI, DT, etc.")
workflow.node("D", "4️⃣ Model Training\nLinear Regression & Random Forest")
workflow.node("E", "5️⃣ Model Evaluation\nR², RMSE, MAE Metrics")
workflow.node("F", "6️⃣ Visualization\nHeatmaps, Histograms, Scatter Plots")
workflow.node("G", "7️⃣ Prediction & Interpretation\nPorosity (Φ) & Permeability (k)")

# Connect steps with arrows
workflow.attr('edge', color='gray40', arrowhead='normal', arrowsize='0.9')
workflow.edge("A", "B")
workflow.edge("B", "C")
workflow.edge("C", "D")
workflow.edge("D", "E")
workflow.edge("E", "F")
workflow.edge("F", "G")

# Render & display
workflow.render("/content/WellLog_Workflow_Diagram", view=False)
Image("/content/WellLog_Workflow_Diagram.png")

# %%
# ======================================================
# 💧 DATA FLOW DIAGRAM — WELL LOGS → ML MODEL → OUTPUT
# ======================================================
from graphviz import Digraph
from IPython.display import Image

dataflow = Digraph("WellLog_DataFlow", format="png")
dataflow.attr(rankdir='LR', size='8', splines='true')

# Node style
dataflow.attr('node', shape='rectangle', style='rounded,filled',
              color='lightblue', fontsize='12', fontname='Arial')

# Input logs (features)
dataflow.node("GR", "Gamma Ray (GR)")
dataflow.node("RHOB", "Bulk Density (RHOB)")
dataflow.node("NPHI", "Neutron Porosity (NPHI)")
dataflow.node("DT", "Sonic Travel Time (DT)")
dataflow.node("CALI", "Caliper (CALI)")

# ML model block
dataflow.attr('node', shape='ellipse', style='filled', color='lightgreen')
dataflow.node("MODEL", "Machine Learning Model\n(Linear Regression + Random Forest)")

# Output nodes
dataflow.attr('node', shape='rectangle', style='rounded,filled', color='lightyellow')
dataflow.node("POR", "Predicted Porosity (Φ)")
dataflow.node("PERM", "Predicted Permeability (k)")

# Arrows: inputs → model → outputs
dataflow.attr('edge', color='gray40', arrowhead='normal', arrowsize='0.9')
for log in ["GR", "RHOB", "NPHI", "DT", "CALI"]:
    dataflow.edge(log, "MODEL")

dataflow.edge("MODEL", "POR")
dataflow.edge("MODEL", "PERM")

# Render & display
dataflow.render("/content/WellLog_DataFlow_Diagram", view=False)
Image("/content/WellLog_DataFlow_Diagram.png")

# %%
# ============================================================
# 📊 WELL LOGS — TABLES ONLY (FINAL)
# ============================================================
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error

# ============================================================
# 🧩 STEP 1 — Ensure dataframe is ready
# ============================================================
try:
    df_clean = df_clean.copy()
except:
    df_clean = df.copy()

# Normalize column names to avoid KeyErrors
df_clean.columns = df_clean.columns.str.strip().str.lower()

# Auto-detect main columns
feature_candidates = ['gr', 'gamma', 'gamma_ray', 'rhob', 'density', 'nphi', 'neutron']
porosity_candidates = ['porosity', 'phi', 'poro']
permeability_candidates = ['permeability', 'perm', 'k']

features = [col for col in df_clean.columns if col in feature_candidates]
por = next((col for col in df_clean.columns if col in porosity_candidates), None)
perm = next((col for col in df_clean.columns if col in permeability_candidates), None)

if not features or por is None or perm is None:
    raise KeyError(f"❌ Missing required columns. Found columns: {list(df_clean.columns)}")

# ============================================================
# 🧮 TABLE 1 — Statistical Summary
# ============================================================
summary_cols = features + [por, perm]
summary_table = df_clean[summary_cols].describe().T
summary_table['Missing Values'] = df_clean[summary_cols].isna().sum()

display(summary_table.style.background_gradient(cmap='Blues')
        .set_caption("📘 Table 1: Statistical Summary of Well Log Parameters"))

# ============================================================
# 🧮 TABLE 2 — Correlation Matrix
# ============================================================
corr_table = df_clean[summary_cols].corr()
display(corr_table.style.background_gradient(cmap='coolwarm')
        .set_caption("📗 Table 2: Correlation Between Log Parameters"))

# ============================================================
# 🧮 TABLE 3 — Model Performance Metrics
# ============================================================
results_table = pd.DataFrame({
    "Model": ["Linear Regression", "Random Forest"],
    "Porosity R²": [
        r2_score(y_por_test, y_por_pred_lr),
        r2_score(y_por_test, y_por_pred_rf)
    ],
    "Permeability R²": [
        r2_score(y_perm_test, y_perm_pred_lr),
        r2_score(y_perm_test, y_perm_pred_rf)
    ],
    "Porosity RMSE": [
        np.sqrt(mean_squared_error(y_por_test, y_por_pred_lr)),
        np.sqrt(mean_squared_error(y_por_test, y_por_pred_rf))
    ],
    "Permeability RMSE": [
        np.sqrt(mean_squared_error(y_perm_test, y_perm_pred_lr)),
        np.sqrt(mean_squared_error(y_perm_test, y_perm_pred_rf))
    ]
})

display(results_table.style.background_gradient(cmap='YlGnBu')
        .set_caption("📙 Table 3: Model Performance Metrics"))

print("✅ All tables generated successfully with captions and color formatting.")
# Out:
# <style type="text/css">
# #T_bff34_row0_col0, #T_bff34_row0_col1, #T_bff34_row0_col2, #T_bff34_row0_col3, #T_bff34_row0_col4, #T_bff34_row0_col5, #T_bff34_row0_col6, #T_bff34_row0_col7, #T_bff34_row1_col8, #T_bff34_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bff34_row0_col8, #T_bff34_row1_col0, #T_bff34_row1_col1, #T_bff34_row1_col2, #T_bff34_row1_col3, #T_bff34_row1_col4, #T_bff34_row1_col5, #T_bff34_row1_col6, #T_bff34_row1_col7, #T_bff34_row2_col1, #T_bff34_row2_col2, #T_bff34_row2_col3, #T_bff34_row2_col4, #T_bff34_row2_col5, #T_bff34_row2_col6, #T_bff34_row2_col7, #T_bff34_row2_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_bff34" class="dataframe">
#   <caption>📘 Table 1: Statistical Summary of Well Log Parameters</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bff34_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_bff34_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_bff34_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_bff34_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_bff34_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_bff34_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_bff34_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_bff34_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_bff34_level0_col8" class="col_heading level0 col8" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bff34_level0_row0" class="row_heading level0 row0" >gamma</th>
#       <td id="T_bff34_row0_col0" class="data row0 col0" >17342.000000</td>
#       <td id="T_bff34_row0_col1" class="data row0 col1" >85.631054</td>
#       <td id="T_bff34_row0_col2" class="data row0 col2" >20.820116</td>
#       <td id="T_bff34_row0_col3" class="data row0 col3" >20.037910</td>
#       <td id="T_bff34_row0_col4" class="data row0 col4" >74.117769</td>
#       <td id="T_bff34_row0_col5" class="data row0 col5" >83.013752</td>
#       <td id="T_bff34_row0_col6" class="data row0 col6" >92.082531</td>
#       <td id="T_bff34_row0_col7" class="data row0 col7" >159.749725</td>
#       <td id="T_bff34_row0_col8" class="data row0 col8" >56</td>
#     </tr>
#     <tr>
#       <th id="T_bff34_level0_row1" class="row_heading level0 row1" >porosity</th>
#       <td id="T_bff34_row1_col0" class="data row1 col0" >17335.000000</td>
#       <td id="T_bff34_row1_col1" class="data row1 col1" >0.001589</td>
#       <td id="T_bff34_row1_col2" class="data row1 col2" >0.000569</td>
#       <td id="T_bff34_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_bff34_row1_col4" class="data row1 col4" >0.001150</td>
#       <td id="T_bff34_row1_col5" class="data row1 col5" >0.001461</td>
#       <td id="T_bff34_row1_col6" class="data row1 col6" >0.002109</td>
#       <td id="T_bff34_row1_col7" class="data row1 col7" >0.003289</td>
#       <td id="T_bff34_row1_col8" class="data row1 col8" >63</td>
#     </tr>
#     <tr>
#       <th id="T_bff34_level0_row2" class="row_heading level0 row2" >perm</th>
#       <td id="T_bff34_row2_col0" class="data row2 col0" >17342.000000</td>
#       <td id="T_bff34_row2_col1" class="data row2 col1" >0.001362</td>
#       <td id="T_bff34_row2_col2" class="data row2 col2" >0.001521</td>
#       <td id="T_bff34_row2_col3" class="data row2 col3" >0.000006</td>
#       <td id="T_bff34_row2_col4" class="data row2 col4" >0.000544</td>
#       <td id="T_bff34_row2_col5" class="data row2 col5" >0.000996</td>
#       <td id="T_bff34_row2_col6" class="data row2 col6" >0.001671</td>
#       <td id="T_bff34_row2_col7" class="data row2 col7" >0.029556</td>
#       <td id="T_bff34_row2_col8" class="data row2 col8" >56</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9f066_row0_col0, #T_9f066_row1_col1, #T_9f066_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9f066_row0_col1, #T_9f066_row0_col2, #T_9f066_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9f066_row1_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_9f066_row1_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_9f066_row2_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# </style>
# <table id="T_9f066" class="dataframe">
#   <caption>📗 Table 2: Correlation Between Log Parameters</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f066_level0_col0" class="col_heading level0 col0" >gamma</th>
#       <th id="T_9f066_level0_col1" class="col_heading level0 col1" >porosity</th>
#       <th id="T_9f066_level0_col2" class="col_heading level0 col2" >perm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f066_level0_row0" class="row_heading level0 row0" >gamma</th>
#       <td id="T_9f066_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9f066_row0_col1" class="data row0 col1" >-0.384197</td>
#       <td id="T_9f066_row0_col2" class="data row0 col2" >-0.511517</td>
#     </tr>
#     <tr>
#       <th id="T_9f066_level0_row1" class="row_heading level0 row1" >porosity</th>
#       <td id="T_9f066_row1_col0" class="data row1 col0" >-0.384197</td>
#       <td id="T_9f066_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9f066_row1_col2" class="data row1 col2" >0.174971</td>
#     </tr>
#     <tr>
#       <th id="T_9f066_level0_row2" class="row_heading level0 row2" >perm</th>
#       <td id="T_9f066_row2_col0" class="data row2 col0" >-0.511517</td>
#       <td id="T_9f066_row2_col1" class="data row2 col1" >0.174971</td>
#       <td id="T_9f066_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4e453_row0_col1, #T_4e453_row0_col2, #T_4e453_row1_col3, #T_4e453_row1_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_4e453_row0_col3, #T_4e453_row0_col4, #T_4e453_row1_col1, #T_4e453_row1_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e453" class="dataframe">
#   <caption>📙 Table 3: Model Performance Metrics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e453_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4e453_level0_col1" class="col_heading level0 col1" >Porosity R²</th>
#       <th id="T_4e453_level0_col2" class="col_heading level0 col2" >Permeability R²</th>
#       <th id="T_4e453_level0_col3" class="col_heading level0 col3" >Porosity RMSE</th>
#       <th id="T_4e453_level0_col4" class="col_heading level0 col4" >Permeability RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e453_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e453_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_4e453_row0_col1" class="data row0 col1" >0.877051</td>
#       <td id="T_4e453_row0_col2" class="data row0 col2" >0.543623</td>
#       <td id="T_4e453_row0_col3" class="data row0 col3" >0.000199</td>
#       <td id="T_4e453_row0_col4" class="data row0 col4" >0.001062</td>
#     </tr>
#     <tr>
#       <th id="T_4e453_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e453_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_4e453_row1_col1" class="data row1 col1" >0.953517</td>
#       <td id="T_4e453_row1_col2" class="data row1 col2" >0.963602</td>
#       <td id="T_4e453_row1_col3" class="data row1 col3" >0.000123</td>
#       <td id="T_4e453_row1_col4" class="data row1 col4" >0.000300</td>
#     </tr>
#   </tbody>
# </table>
# ✅ All tables generated successfully with captions and color formatting.

# %%
# ============================================================
# 📊 ENHANCED CORRELATION TABLE — WELL LOG PARAMETERS
# ============================================================
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# --- Ensure dataframe is ready ---
try:
    df_clean = df_clean.copy()
except:
    df_clean = df.copy()

# Convert all column names to lowercase for consistency
df_clean.columns = df_clean.columns.str.strip().str.lower()

# --- Select only numeric columns for correlation ---
numeric_cols = df_clean.select_dtypes(include=[np.number])

if numeric_cols.empty:
    raise ValueError("❌ No numeric columns found for correlation matrix.")

# --- Compute correlation ---
corr_matrix = numeric_cols.corr()

# ============================================================
# 🧮 TABLE — Display correlation matrix as a big table
# ============================================================
corr_table = corr_matrix.round(3)  # round to 3 decimal places
display(corr_table.style.background_gradient(cmap='coolwarm')
        .set_caption("📘 Table: Expanded Correlation Matrix of Well Log Parameters")
        .set_table_styles([{'selector': 'caption',
                            'props': [('color', 'black'), ('font-size', '16px'), ('font-weight', 'bold')]}]))

# ============================================================
# 📈 CHART — Large, clear correlation heatmap
# ============================================================
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap="coolwarm", annot=True, fmt=".2f",
            linewidths=0.5, cbar_kws={'shrink': 0.8}, annot_kws={"size":10})
plt.title("Correlation Heatmap of Well Log Parameters", fontsize=16, weight='bold', pad=15)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# ============================================================
# 💾 (Optional) Save to Excel for your report
# ============================================================
c
# Out:
# <style type="text/css">
# #T_4f1b7 caption {
#   color: black;
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_4f1b7_row0_col0, #T_4f1b7_row1_col1, #T_4f1b7_row2_col2, #T_4f1b7_row3_col3, #T_4f1b7_row4_col4, #T_4f1b7_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4f1b7_row0_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_4f1b7_row0_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_4f1b7_row0_col3, #T_4f1b7_row0_col5, #T_4f1b7_row1_col2, #T_4f1b7_row1_col4, #T_4f1b7_row2_col1, #T_4f1b7_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4f1b7_row0_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_4f1b7_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_4f1b7_row1_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_4f1b7_row1_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_4f1b7_row2_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_4f1b7_row2_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_4f1b7_row2_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_4f1b7_row2_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_4f1b7_row3_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_4f1b7_row3_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_4f1b7_row3_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4f1b7_row3_col5 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_4f1b7_row4_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_4f1b7_row4_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_4f1b7_row4_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_4f1b7_row4_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_4f1b7_row4_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_4f1b7_row5_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_4f1b7_row5_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_4f1b7_row5_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_4f1b7_row5_col3 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_4f1b7_row5_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4f1b7" class="dataframe">
#   <caption>📘 Table: Expanded Correlation Matrix of Well Log Parameters</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f1b7_level0_col0" class="col_heading level0 col0" >dept</th>
#       <th id="T_4f1b7_level0_col1" class="col_heading level0 col1" >gamma</th>
#       <th id="T_4f1b7_level0_col2" class="col_heading level0 col2" >perm</th>
#       <th id="T_4f1b7_level0_col3" class="col_heading level0 col3" >porosity</th>
#       <th id="T_4f1b7_level0_col4" class="col_heading level0 col4" >resistivity</th>
#       <th id="T_4f1b7_level0_col5" class="col_heading level0 col5" >lith</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f1b7_level0_row0" class="row_heading level0 row0" >dept</th>
#       <td id="T_4f1b7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4f1b7_row0_col1" class="data row0 col1" >0.004000</td>
#       <td id="T_4f1b7_row0_col2" class="data row0 col2" >0.029000</td>
#       <td id="T_4f1b7_row0_col3" class="data row0 col3" >-0.592000</td>
#       <td id="T_4f1b7_row0_col4" class="data row0 col4" >0.071000</td>
#       <td id="T_4f1b7_row0_col5" class="data row0 col5" >-0.543000</td>
#     </tr>
#     <tr>
#       <th id="T_4f1b7_level0_row1" class="row_heading level0 row1" >gamma</th>
#       <td id="T_4f1b7_row1_col0" class="data row1 col0" >0.004000</td>
#       <td id="T_4f1b7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4f1b7_row1_col2" class="data row1 col2" >-0.512000</td>
#       <td id="T_4f1b7_row1_col3" class="data row1 col3" >-0.384000</td>
#       <td id="T_4f1b7_row1_col4" class="data row1 col4" >-0.145000</td>
#       <td id="T_4f1b7_row1_col5" class="data row1 col5" >-0.404000</td>
#     </tr>
#     <tr>
#       <th id="T_4f1b7_level0_row2" class="row_heading level0 row2" >perm</th>
#       <td id="T_4f1b7_row2_col0" class="data row2 col0" >0.029000</td>
#       <td id="T_4f1b7_row2_col1" class="data row2 col1" >-0.512000</td>
#       <td id="T_4f1b7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4f1b7_row2_col3" class="data row2 col3" >0.175000</td>
#       <td id="T_4f1b7_row2_col4" class="data row2 col4" >0.685000</td>
#       <td id="T_4f1b7_row2_col5" class="data row2 col5" >0.266000</td>
#     </tr>
#     <tr>
#       <th id="T_4f1b7_level0_row3" class="row_heading level0 row3" >porosity</th>
#       <td id="T_4f1b7_row3_col0" class="data row3 col0" >-0.592000</td>
#       <td id="T_4f1b7_row3_col1" class="data row3 col1" >-0.384000</td>
#       <td id="T_4f1b7_row3_col2" class="data row3 col2" >0.175000</td>
#       <td id="T_4f1b7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4f1b7_row3_col4" class="data row3 col4" >-0.056000</td>
#       <td id="T_4f1b7_row3_col5" class="data row3 col5" >0.926000</td>
#     </tr>
#     <tr>
#       <th id="T_4f1b7_level0_row4" class="row_heading level0 row4" >resistivity</th>
#       <td id="T_4f1b7_row4_col0" class="data row4 col0" >0.071000</td>
#       <td id="T_4f1b7_row4_col1" class="data row4 col1" >-0.145000</td>
#       <td id="T_4f1b7_row4_col2" class="data row4 col2" >0.685000</td>
#       <td id="T_4f1b7_row4_col3" class="data row4 col3" >-0.056000</td>
#       <td id="T_4f1b7_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_4f1b7_row4_col5" class="data row4 col5" >0.066000</td>
#     </tr>
#     <tr>
#       <th id="T_4f1b7_level0_row5" class="row_heading level0 row5" >lith</th>
#       <td id="T_4f1b7_row5_col0" class="data row5 col0" >-0.543000</td>
#       <td id="T_4f1b7_row5_col1" class="data row5 col1" >-0.404000</td>
#       <td id="T_4f1b7_row5_col2" class="data row5 col2" >0.266000</td>
#       <td id="T_4f1b7_row5_col3" class="data row5 col3" >0.926000</td>
#       <td id="T_4f1b7_row5_col4" class="data row5 col4" >0.066000</td>
#       <td id="T_4f1b7_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 'LITH'

# %%
# ================================================================
# 🎨 GRAPHICAL ABSTRACT: WELL LOG INTERPRETATION USING ML
# ================================================================
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Create figure
fig, ax = plt.subplots(figsize=(14, 6))
ax.axis("off")

# ------------------------------------------------------------
# Define main steps
# ------------------------------------------------------------
steps = [
    "WELL LOG DATA\n(GR, RHOB, NPHI, DT, etc.)",
    "DATA PREPROCESSING\n(Merging, Cleaning, Normalization)",
    "FEATURE SELECTION\n(Correlation, Importance Analysis)",
    "MACHINE LEARNING MODELS\nLinear Regression & Random Forest",
    "PREDICTED OUTPUTS\nPorosity & Permeability"
]

# Define box positions
x_positions = [0.05, 0.25, 0.45, 0.65, 0.85]
colors = ["#b3cde3", "#ccebc5", "#decbe4", "#fed9a6", "#fbb4ae"]

# Draw boxes
for i, (x, text, color) in enumerate(zip(x_positions, steps, colors)):
    box = mpatches.FancyBboxPatch((x, 0.4), 0.15, 0.3,
                                  boxstyle="round,pad=0.02",
                                  fc=color, ec="black", lw=1.5)
    ax.add_patch(box)
    ax.text(x + 0.075, 0.55, text, ha="center", va="center",
            fontsize=11, fontweight='bold', wrap=True)

# ------------------------------------------------------------
# Add arrows between steps
# ------------------------------------------------------------
for i in range(len(x_positions) - 1):
    ax.annotate("", xy=(x_positions[i+1]-0.02, 0.55),
                xytext=(x_positions[i]+0.17, 0.55),
                arrowprops=dict(arrowstyle="->", lw=2, color="gray"))

# ------------------------------------------------------------
# Add title
# ------------------------------------------------------------
ax.text(0.5, 0.9,
        "Graphical Abstract: Well Logging Interpretation through Machine Learning",
        fontsize=14, ha="center", va="center", fontweight='bold')

# Add note
ax.text(0.5, 0.1,
        "Workflow: Raw Well Logs → Preprocessing → Feature Selection → ML Prediction → Porosity & Permeability Estimation",
        fontsize=10, ha="center", va="center", color="dimgray")

plt.tight_layout()
plt.show()

# %%
# ======================================================
# 🧩 WELL LOG INTERPRETATION WORKFLOW DIAGRAM (15× Bigger)
# ======================================================
from graphviz import Digraph
from IPython.display import Image

workflow = Digraph("WellLog_Workflow", format="png")

# MASSIVE canvas (≈ 15x)
workflow.attr(rankdir='LR', size='120,60', splines='true')

# Huge nodes for poster display
workflow.attr('node', shape='rectangle', style='rounded,filled',
              color='lightgreen', fontsize='90', penwidth='10', fontname='Arial')

# Workflow steps
workflow.node("A", "1️⃣ Data Acquisition\nCollect LAS Well Log Files (A10–C5)")
workflow.node("B", "2️⃣ Data Preprocessing\nRead LAS, Clean, Merge, Scale")
workflow.node("C", "3️⃣ Feature Selection\nGR, RHOB, NPHI, DT, etc.")
workflow.node("D", "4️⃣ Model Training\nLinear Regression & Random Forest")
workflow.node("E", "5️⃣ Model Evaluation\nR², RMSE, MAE Metrics")
workflow.node("F", "6️⃣ Visualization\nHeatmaps, Histograms, Scatter Plots")
workflow.node("G", "7️⃣ Prediction & Interpretation\nPorosity (Φ) & Permeability (k)")

# Very thick arrows
workflow.attr('edge', color='gray30', arrowhead='normal', arrowsize='6', penwidth='6')

# Connections
workflow.edge("A", "B")
workflow.edge("B", "C")
workflow.edge("C", "D")
workflow.edge("D", "E")
workflow.edge("E", "F")
workflow.edge("F", "G")

# Render output
workflow.render("/content/WellLog_Workflow_Diagram", view=False)
Image("/content/WellLog_Workflow_Diagram.png")

# %%
# ======================================================
# 🧩 WELL LOG WORKFLOW (Half-Page Vertical)
# ======================================================
from graphviz import Digraph
from IPython.display import Image

workflow = Digraph("WellLog_Workflow", format="png")

# Half-page layout
workflow.attr(rankdir='TB', size='7,9', splines='true')   # <--- smaller canvas

# Smaller nodes for compact layout
workflow.attr('node', shape='rectangle', style='rounded,filled',
              color='lightgreen', fontsize='18', penwidth='1.5', fontname='Arial')

# Steps (unchanged text but smaller)
workflow.node("A", "Data Acquisition\n(LAS Files)")
workflow.node("B", "Data Preprocessing\n(Clean, Merge, Normalize)")
workflow.node("C", "Feature Selection\n(GR, RHOB, NPHI, DT)")
workflow.node("D", "Model Training\n(LR & Random Forest)")
workflow.node("E", "Model Evaluation\n(R², RMSE, MAE)")
workflow.node("F", "Visualization\n(Plots & Heatmaps)")
workflow.node("G", "Prediction & Interpretation\n(Φ & k)")

# Smaller arrows & spacing
workflow.attr('edge', color='gray40', arrowsize='0.9', penwidth='1.3')
workflow.edge("A", "B")
workflow.edge("B", "C")
workflow.edge("C", "D")
workflow.edge("D", "E")
workflow.edge("E", "F")
workflow.edge("F", "G")

# Render & Preview
workflow.render("/content/WellLog_Workflow_Diagram", view=False)
Image("/content/WellLog_Workflow_Diagram.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots(figsize=(6, 9))
ax.axis("off")

# Steps
steps = [
    "WELL LOG INPUTS\n(GR, RHOB, NPHI, DT)",
    "DATA CLEANING\nOutlier Removal, Normalization",
    "FEATURE ENGINEERING\nCorrelation / PCA / Scaling",
    "ML MODEL\nRandom Forest / Regression",
    "PREDICTED PROPERTIES\nPorosity (Φ) & Permeability (k)",
    "VALIDATION\nR², RMSE, Core Data Check"
]

# Colors
colors = ["#a7c7e7", "#b6e3b6", "#f4c2c2", "#f8d49d", "#c9b6e4", "#ffd59e"]

# Box vertical positions
y_positions = [0.78, 0.64, 0.50, 0.36, 0.22, 0.08]

# Draw Boxes (increased width from 0.70 to 0.75)
for text, y, color in zip(steps, y_positions, colors):
    box = mpatches.FancyBboxPatch((0.125, y), 0.75, 0.10, # Adjusted x-position (0.125) and width (0.75)
                                  boxstyle="round,pad=0.035",
                                  fc=color, ec="black", lw=1.6)
    ax.add_patch(box)
    ax.text(0.50, y + 0.05, text,
            ha="center", va="center", fontsize=10, fontweight='bold', wrap=True)

# ⬇️ DOWNWARD ARROWS (keeping them small)
for i in range(len(y_positions) - 1):
    ax.annotate("",
                xy=(0.50, y_positions[i+1] + 0.11), # arrow head (Target: top of lower box i+1)
                xytext=(0.50, y_positions[i] - 0.01),  # arrow tail (Start: bottom of upper box i)
                arrowprops=dict(arrowstyle="simple", lw=2.0, mutation_scale=15, color="black"))

# Title (no box, spaced from first box)
ax.text(0.50, 0.93,
        "Graphical Abstract: Well Logging Interpretation Through Machine Learning",
        ha="center", va="center", fontsize=12.5, fontweight='bold')

plt.tight_layout()
plt.savefig("workflow_diagram_larger_boxes_v3.png")
print("workflow_diagram_larger_boxes_v3.png")
# Out:
# workflow_diagram_larger_boxes_v3.png
